# %% [markdown]
#  This is the brief workthrough of the program MWR. Good Luck

# %%
print("hello world")
# Out:
# hello world

# %% [markdown]
# You can download turorial dataset from https://drive.google.com/drive/folders/1wdO4NozmWMA7bPa-RTfzrZRgAmKwTcR3?usp=sharing
