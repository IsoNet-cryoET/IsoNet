# %% [markdown]
# ## Mask Generation
# Sub-tomograms are randomly sampled through the tomogram.A binary mask with the same size as the tomogram can be used to constrain the sampling area to the region containing richer information.The mask is generated by comparing the local variance to the global variance.

# %%
# !maskGene.py pp676-bin4-wbp.rec pp676-bin4-wbp-mask.rec
