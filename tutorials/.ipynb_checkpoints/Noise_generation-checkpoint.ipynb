# %% [markdown]
# ## Noise Generation
# To help accelerate the missing wedge information retrieval, some artificial noise, which mimics the noise pattern in original tomograph, can be added to the sub-tomograms.
# Noise cubes are 3d arrays and also exhibit missing wedge effect along y axis

# %% [markdown]
# ### Recommanded parameters
# The size of noise cubes have to be the same as subtomograms' in the training data, usually 64 for bin4 data and 96 or 128 for bin2 data.The default tilts' angle range -60 to +60 degree.
# For example, you can generate 1000 noise cubes of size 64x64x64 in your filefolder *./noise64* using 20 cpus with default settings:

# %%
# %%bash
#
# mwr_cli generate_noise -h
# Out:
# bash: line 2: mwr_cli: command not found
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# <ipython-input-2-9f53fff9735d> in <module>
# ----> 1 get_ipython().run_cell_magic('bash', '', '\nmwr_cli generate_noise -h\n')
#
# ~/software/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2360             with self.builtin_trap:
#    2361                 args = (magic_arg_s, cell)
# -> 2362                 result = fn(*args, **kwargs)
#    2363             return result
#    2364
#
# ~/software/anaconda3/lib/python3.7/site-packages/IPython/core/magics/script.py in named_script_magic(line, cell)
#     140             else:
#     141                 line = script
# --> 142             return self.shebang(line, cell)
#     143
#     144         # write a basic docstring:
#
# </home/heng/software/anaconda3/lib/python3.7/site-packages/decorator.py:decorator-gen-110> in shebang(self, line, cell)
#
# ~/software/anaconda3/lib/python3.7/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# ~/software/anaconda3/lib/python3.7/site-packages/IPython/core/magics/script.py in shebang(self, line, cell)
#     243             sys.stderr.flush()
#     244         if args.raise_error and p.returncode!=0:
# --> 245             raise CalledProcessError(p.returncode, cell, output=out, stderr=err)
#     246
#     247     def _run_script(self, p, cell, to_close):
#
# CalledProcessError: Command 'b'\nmwr_cli generate_noise -h\n'' returned non-zero exit status 127.
